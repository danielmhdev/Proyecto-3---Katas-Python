# %% [markdown]
# 1. Escribe una función que reciba una cadena de texto como parámetro y devuelva un diccionario con las frecuencias de cada letra en la cadena. Los espacios no deben ser considerados.

# %%
from functools import reduce
from idlelib.debugger_r import close_remote_debugger


def frecuencia_letras(cadena):
    frecuencia = {}
    cadena = cadena.lower()
    for letra in cadena:
        if letra != " ": # Ignoramos los espacios, por lo que solo entramos si no es espacio
            if letra in frecuencia:
                frecuencia[letra] += 1
            else:
                frecuencia[letra] = 1
    return frecuencia

prueba = "Estoy cansado jefe"
print (frecuencia_letras(prueba))
# Out:
# {'e': 3, 's': 2, 't': 1, 'o': 2, 'y': 1, 'c': 1, 'a': 2, 'n': 1, 'd': 1, 'j': 1, 'f': 1}

# %% [markdown]
# 2. Dada una lista de números, obtén una nueva lista con el doble de cada valor. Usa la función map().

# %%
lista_inicial = [1,2,4,6,8,10]
def duplicar (n):
    return n * 2
lista_final = map(duplicar, lista_inicial)
print((list(lista_final)))
# Out:
# [2, 4, 8, 12, 16, 20]

# %% [markdown]
# 3. Escribe una función que tome una lista de palabras y una palabra objetivo como parámetros.
# La función debe devolver una lista con todas las palabras de la lista original que contengan la palabra objetivo.

# %%
lista_palabras = ["sol", "girasol", "solar", "luna", "consola", "parasol", "soldado", "mar"] #Creo una lista de palabras con juego.

def lista_filtrada(lista, objetivo):
    resultado = []
    for palabra in lista:
        if objetivo.lower() in palabra.lower(): #lower para evitar problemas con mayus.
            resultado.append(palabra) # agrego a la nueva lista.
    return set(resultado) #set por si alguna palabra se hubiera colado más de una vez.

print(lista_filtrada(lista_palabras, "sol"))
# Out:
# {'soldado', 'solar', 'sol', 'parasol', 'girasol', 'consola'}

# %% [markdown]
# 4. Genera una función que calcule la diferencia entre los valores de dos listas. Usa la función map().

# %%
ingresos = [100, 200, 150, 300]
gastos = [10, 30, 50, 100]

def resta(ingresos,gastos):
    return ingresos - gastos
resultado = map(resta, ingresos,gastos)
print (list(resultado))
# Out:
# [90, 170, 100, 200]

# %% [markdown]
# 5. Escribe una función que tome una lista de números como parámetro y un valor opcional nota_aprobado (por defecto 5).
# La función debe calcular la media de los números en la lista y determinar si la media es mayor o igual que nota_aprobado. Si es así, el estado será "aprobado"; de lo contrario, "suspenso". La función debe devolver una tupla que contenga la media y el estado.

# %%
lista_notas = [4,5,3,6,9,10,2,3,1,4]
def calcular_aprobado(lista_notas, nota_aprobado = 5):
    media = 0
    for nota in lista_notas:
        media += nota
    nota_media = media/len(lista_notas)
    if nota_media >= nota_aprobado:
        return "Has aprobado", nota_media #Definimos la tupla aqui.
    else:
        return "Has suspendido", nota_media

print(calcular_aprobado(lista_notas))
# Out:
# ('Has suspendido', 4.7)

# %% [markdown]
# 6. Escribe una función que calcule el factorial de un número de manera recursiva.

# %%
n= 5
def calcular_factorial(n):
    if n >1:
        return n * calcular_factorial(n-1)
    else:
        return 1

print(f"El factorial de {n}: es {calcular_factorial(5)}")
# Out:
# El factorial de 5: es 120

# %% [markdown]
# 7. Genera una función que convierta una lista de tuplas a una lista de strings. Usa la función map().

# %%
pasajeros = [
    ("Luis", "Gómez", 42),
    ("Marta", "Vega", 15),
    ("Pedro", "Sanz", 33)
]
def conver_string(tupla):
    return str(tupla)

resultado_lista = (map(conver_string, pasajeros))
print (list(resultado_lista))
# Out:
# ["('Luis', 'Gómez', 42)", "('Marta', 'Vega', 15)", "('Pedro', 'Sanz', 33)"]

# %% [markdown]
# 8. Escribe un programa que pida al usuario dos números e intente dividirlos. Si el usuario ingresa un valor no numérico o intenta dividir por cero, maneja esas excepciones de manera adecuada y muestra un mensaje indicando si la división fue exitosa o no.

# %%
def dividir_num():
    try:
        n1 = float(input("Introduce el dividendo: "))
        n2 = float(input("Introduce el divisor: "))
        resultado_div = n1/n2
    except ValueError:
        print("Numero no valido")
    except ZeroDivisionError:
        print("No se puede dividir por cero")
    else: #Si el try se ejecuta correctamente
        print(f"El resultado es: {resultado_div}")
dividir_num()
# Out:
# No se puede dividir por cero

# %% [markdown]
# 9. Escribe una función que tome una lista de nombres de mascotas como parámetro y devuelva una nueva lista excluyendo ciertas mascotas prohibidas en España. La lista de mascotas a excluir es ["Mapache", "Tigre", "Serpiente Pitón", "Cocodrilo", "Oso"]. Usa la función filter().

# %%
mascotas_excluidas = ["Mapache", "Tigre", "Serpiente Pitón", "Cocodrilo", "Oso"]
mascotas = ["Perro", "Mapache", "Gato", "Tigre", "Hamster", "Cocodrilo"]

def mascotas_permitidas(mascotas):
    mascotas_permitidas = list(filter(lambda x: x not in mascotas_excluidas, mascotas))
    return mascotas_permitidas

print(mascotas_permitidas(mascotas))
# Out:
# ['Perro', 'Gato', 'Hamster']

# %% [markdown]
# 10. Escribe una función que reciba una lista de números y calcule su promedio. Si la lista está vacía, lanza una excepción personalizada y maneja el error adecuadamente.

# %%
def calcular_promedio(lista):
    if len(lista) == 0:
        raise ValueError("Lista vacia")
    return sum(lista) / len(lista)
lista_numeros = [8,9]
try:
    print(f"El promedio es: {calcular_promedio(lista_numeros)}")
except ValueError as e:
    print(f"️Error: {e}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# El promedio es: 8.5

# %% [markdown]
# 11. Escribe un programa que pida al usuario que introduzca su edad. Si el usuario ingresa un valor no numérico o un valor fuera del rango esperado (por ejemplo, menor que 0 o mayor que 120), maneja las excepciones adecuadamente.

# %%
def validar_edad():
        try:
            edad = int(input("Por favor, introduce tu edad: "))
            if edad < 0 or edad > 120:
                raise ValueError("La edad debe ser entre 0-120")
            else:
                return f"Edad registrada correctamente: {edad}"
        except ValueError as e:
            print(f"Error: {e}")

validar_edad()
# Out:
# Error: La edad debe ser entre 0-120

# %% [markdown]
# 12. Genera una función que, al recibir una frase, devuelva una lista con la longitud de cada palabra. Usa la función map().

# %%
def contar_letras(frase):
    lista_palabras = frase.split()
    resultado = list(map(len, lista_palabras))
    return resultado

texto = "Estoy muy cansado jefe, necesito tocar grass"
print(contar_letras(texto))
# Out:
# [5, 3, 7, 5, 8, 5, 5]

# %% [markdown]
# 13. Genera una función que, para un conjunto de caracteres, devuelva una lista de tuplas con cada letra en mayúsculas y minúsculas. Las letras no pueden estar repetidas. Usa la función map().

# %%
texto = "banana"

def generar_tuplas(cadena):
    resultado = list(map(lambda letra: (letra.upper(), letra.lower()), set(cadena)))
    return resultado

print(generar_tuplas(texto))
# Out:
# [('N', 'n'), ('A', 'a'), ('B', 'b')]

# %% [markdown]
# 14. Crea una función que retorne las palabras de una lista que comiencen con una letra en específico. Usa la función filter().

# %%
palabras = ["Manzana", "Banana", "Melón", "Pera", "Mango", "Kiwi"]

def filtrar_por_letra(lista, letra):
    return list(filter(lambda palabra: palabra.startswith(letra), lista))

print(filtrar_por_letra(palabras, "M"))
# Out:
# ['Manzana', 'Melón', 'Mango']

# %% [markdown]
# 15. Crea una función lambda que sume 3 a cada número de una lista dada.

# %%
numeros = [1, 2, 3, 4, 5]

sumar_tres = list(map(lambda x: x + 3, numeros))

print(resultado)
# Out:
# [4, 5, 6, 7, 8]

# %% [markdown]
# 16. Escribe una función que tome una cadena de texto y un número entero n como parámetros y devuelva una lista de todas las palabras que sean más largas que n. Usa la función filter().

# %%
texto1 = "Lorem ipsum dolor sit amet, consectetur adipiscing elit"
numero = 3

def palabras_mas_largas(texto,numero):
    palabras1 = texto.split(" ")
    resultado = list(filter(lambda x: len(x) > numero, palabras1))
    return resultado

print(palabras_mas_largas(texto1,numero))
# Out:
# ['Lorem', 'ipsum', 'dolor', 'amet,', 'consectetur', 'adipiscing', 'elit']

# %% [markdown]
# 17. Crea una función que tome una lista de dígitos y devuelva el número correspondiente. Por ejemplo, [5,7,2] corresponde al número 572. Usa la función reduce().

# %%
from functools import reduce
lista_digitos =  [5,7,2]

def conversion_digitos (lista):
    resultado = reduce(lambda acumulador, x:acumulador*10 + x,lista)
    return resultado
print(conversion_digitos(lista_digitos))
# Out:
# 572

# %% [markdown]
# 18. Escribe un programa en Python que cree una lista de diccionarios con información de estudiantes (nombre, edad, calificación) y use filter para extraer a los estudiantes con una calificación mayor o igual a 90.

# %%
estudiantes = [
    {'nombre': 'Juan', 'edad': 20, 'calificacion': 85},
    {'nombre': 'Maria', 'edad': 22, 'calificacion': 90},
    {'nombre': 'Pedro', 'edad': 21, 'calificacion': 95},
    {'nombre': 'Elena', 'edad': 19, 'calificacion': 70}
]
def calificacion_alta(lista):
    resultado = list(filter(lambda x: x["calificacion"] >= 90, lista))
    return resultado

print(calificacion_alta(estudiantes))
# Out:
# [{'nombre': 'Maria', 'edad': 22, 'calificacion': 90}, {'nombre': 'Pedro', 'edad': 21, 'calificacion': 95}]

# %% [markdown]
# 19. Crea una función lambda que filtre los números impares de una lista dada.

# %%
numeros = [1, 2, 3, 4, 5, 6, 7, 8, 9]
impares = list(filter(lambda x: x % 2 == 1, numeros))
print(impares)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# 20. Para una lista con elementos de tipo integer y string, obtén una nueva lista solo con los valores int. Usa la función filter().

# %%
elementos = [1,"juan",4, "coche", 7, "perro", 6 ,"magdalena"]

def solo_int(elementos):
    resultado = list(filter(lambda x: type(x) == int, elementos ))
    return resultado
print (solo_int(elementos))
# Out:
# [1, 4, 7, 6]

# %% [markdown]
# 21. Crea una función que calcule el cubo de un número dado mediante una función lambda.

# %%
numero_cubo = 5

calculo_cubo = lambda x: x ** 3
print(calculo_cubo(5))
# Out:
# 125

# %% [markdown]
# 22. Dada una lista numérica, obtén el producto total de los valores. Usa la función reduce().

# %%
from functools import reduce
lista_numerica = [5,4,6,7,8,8,9]
def calculo_producto(lista):
    return reduce(lambda acumulador, x: acumulador * x, lista)
print(calculo_producto(lista_numerica))
# Out:
# 483840

# %% [markdown]
# 23. Concatena una lista de palabras. Usa la función reduce().

# %%
from functools import reduce
lista_palabros = ["Martillo", "es", "igual", "que", "torpedo"]

def concatenar(lista):
    return reduce(lambda acumulador ,x: acumulador + " "+ x, lista)
print(concatenar(lista_palabros))
# Out:
# Martillo es igual que torpedo

# %% [markdown]
# 24. Calcula la diferencia total en los valores de una lista. Usa la función reduce().

# %%
from functools import reduce
lista_numerica = [5,4,6,7,8,8,9]
def calculo_resta(lista):
    return reduce(lambda acumulador,x: acumulador - x,lista)

print(calculo_resta(lista_numerica))
# Out:
# -37

# %% [markdown]
# 25.Crea una función que cuente el número de caracteres en una cadena de texto dada.

# %%
from functools import reduce

caracteres = "Me gusta la fruta"
def numero_caracteres(cadena):
    resultado = reduce(lambda acumulador , x: acumulador + len(x),cadena,0)
    return resultado

print(numero_caracteres(caracteres))
# Out:
# 17

# %% [markdown]
# 26. Crea una función lambda que calcule el resto de la división entre dos números dados.

# %%
num1= 25
num2= 7

calculo_resto = lambda x, y: x % y
print(calculo_resto(num1,num2))
# Out:
# 4

# %% [markdown]
# 27. Crea una función que calcule el promedio de una lista de números.

# %%
lista_numerica = [5,4,6,7,8,8,9]
def promedio_numeros(lista):
    suma = reduce(lambda acumulador, x: (acumulador +x), lista)
    resultado = suma /len(lista)
    return resultado
print(promedio_numeros(lista_numerica))
# Out:
# 6.714285714285714

# %% [markdown]
# 28.Crea una función que busque y devuelva el primer elemento duplicado en una lista dada.

# %%
lista_numerica = [5,4,8,7,4,8,9]
def encontrar_duplicado(lista):
    recuento = set()
    for numero in lista:
        if numero in lista :
            return numero
        recuento.add(numero)
    return "No hay repetición"
print(encontrar_duplicado(lista_numeros))
# Out:
# 8

# %% [markdown]
# 29. Crea una función que convierta una variable en una cadena de texto y enmascare todos los caracteres con el carácter '#' excepto los últimos cuatro.

# %%
def enmascarar_text(texto):
    longitud = len(texto)
    visible = texto[-4:]
    almohadillas = "#" * (longitud-4)
    return almohadillas + visible
print(enmascarar_text("123456789"))
# Out:
# #####6789

# %% [markdown]
# 30. Crea una función que determine si dos palabras son anagramas, es decir, si están formadas por las mismas letras pero en diferente orden.

# %%
def son_anagramas(palabra1, palabra2):
    palabra1 = palabra1.lower()
    palabra2 = palabra2.lower()
    return sorted(palabra1) == sorted(palabra2)

print(son_anagramas("Roma", "Amor"))
# Out:
# True

# %% [markdown]
# 31. Crea una función que solicite al usuario ingresar una lista de nombres y luego un nombre para buscar en esa lista. Si el nombre está en la lista, imprime un mensaje indicando que fue encontrado; de lo contrario, lanza una excepción.

# %%
def buscador_nombres():
    solicitud_nombres = input("Introduce nombres separados por comas (ej: Ana,Juan,Pedro): ")
    lista_nombres = solicitud_nombres.split(",")
    lista_nombres = [nombre.strip() for nombre in lista_nombres]
    busqueda = input("¿A quién quieres buscar?: ")

    if busqueda in lista_nombres:
        print(f"¡Genial! {busqueda} está en la lista.")
    else:
        raise ValueError(f"Error: El nombre '{busqueda}' no aparece en la lista.")
try:
    print(buscador_nombres())
except Exception as e:
    print(e)
# Out:
# ¡Genial! Juan está en la lista.

# %% [markdown]
# 32. Crea una función que tome un nombre completo y una lista de empleados, busque el nombre en la lista y devuelva el puesto del empleado si se encuentra; de lo contrario, devuelve un mensaje indicando que la persona no trabaja aquí.

# %%
empleados = {
    "Ana López": "Enfermera",
    "Juan Pérez": "Desarrollador Junior",
    "María García": "Jefa de Proyecto"
}

def obtener_puesto(nombre, empleados):
    if nombre in empleados:
        return empleados[nombre]
    else:
        return "Esa persona no trabaja aquí."

print(obtener_puesto("Ana López", empleados))
print(obtener_puesto("Carlos Ruiz", empleados))
# Out:
# Enfermera
# Esa persona no trabaja aquí.

# %% [markdown]
# 33. Crea una función lambda que sume elementos correspondientes de dos listas dadas.

# %%
lista_1 = [1, 2, 3, 4]
lista_2 = [10, 20, 30, 40]

def sumar_listas(l1, l2):
    resultado = map(lambda x, y: x + y, l1, l2)
    return list(resultado)

print(sumar_listas(lista_1, lista_2))
# Out:
# [11, 22, 33, 44]

# %% [markdown]
# 34. Crea la clase Arbol
# - Define un árbol genérico con un tronco y ramas como atributos.
# - Métodos disponibles: crecer_tronco, nueva_rama, crecer_ramas, quitar_rama, info_arbol.
# - Código a seguir:
#     - Inicializar un árbol con un tronco de longitud 1 y una lista vacía de ramas.
#     - Implementar el método crecer_tronco para aumentar la longitud del tronco en una unidad.
#     - Implementar el método nueva_rama para agregar una nueva rama de longitud 1 a la lista de ramas.
#     - Implementar el método crecer_ramas para aumentar en una unidad la longitud de todas las ramas existentes.
#     - Implementar el método quitar_rama para eliminar una rama en una posición específica.
#     - Implementar el método info_arbol para devolver información sobre la longitud del tronco, el número de ramas y sus longitudes.
# - Caso de uso:
#     - a. Crear un árbol.
#     - b. Hacer crecer el tronco una unidad.
#     - c. Añadir una nueva rama.
#     - d. Hacer crecer todas las ramas una unidad.
#     - e. Añadir dos nuevas ramas.
#     - f. Retirar la rama situada en la posición 2.
#     - g. Obtener información sobre el árbol.

# %%
class Arbol:
    def __init__(self):
        self.tronco = 1
        self.ramas = []

    def crecer_tronco(self):
        self.tronco += 1

    def nueva_rama(self):
        self.ramas.append(1) # Añade una rama de longitud 1

    def crecer_ramas(self):
        self.ramas = [rama + 1 for rama in self.ramas]

    def quitar_rama(self, posicion):
            self.ramas.pop(posicion)

    def info_arbol(self):
        return {
            "Longitud Tronco": self.tronco,
            "Número de ramas": len(self.ramas),
            "Longitud de ramas": self.ramas
        }

mi_arbol = Arbol()
mi_arbol.crecer_tronco()
mi_arbol.nueva_rama()
mi_arbol.crecer_ramas()
mi_arbol.nueva_rama()
mi_arbol.nueva_rama()
mi_arbol.quitar_rama(2)
print(mi_arbol.info_arbol())
# Out:
# {'Longitud Tronco': 2, 'Número de ramas': 2, 'Longitud de ramas': [2, 1]}

# %% [markdown]
# 35. Crea la clase UsuarioBanco
#     - Representa a un usuario de un banco con su nombre, saldo y si tiene o no cuenta corriente.
#     - Métodos: retirar_dinero, transferir_dinero, agregar_dinero.
#     - Código a seguir:
#         - Inicializar un usuario con nombre, saldo y un indicador (True o False) de cuenta corriente.
#         - Implementar retirar_dinero para sustraer dinero del saldo, lanzando un error si no es posible.
#         - Implementar transferir_dinero para transferir dinero desde otro usuario, lanzando un error en caso de fallo.
#         - Implementar agregar_dinero para aumentar el saldo del usuario.
#     - Caso de uso:
#         - a. Crear dos usuarios: "Alicia" con saldo inicial de 100 y "Bob" con saldo inicial de 50, ambos con cuenta corriente.
#         - b. Agregar 20 unidades al saldo de Bob.
#         - c. Transferir 80 unidades de Bob a Alicia.
#         - d. Retirar 50 unidades del saldo de Alicia.

# %%
class UsuarioBanco:
    def __init__(self, nombre, saldo, cuenta_corriente):
        self.nombre = nombre
        self.saldo = saldo
        self.cuenta_corriente = cuenta_corriente

    def agregar_dinero(self, cantidad):
        self.saldo += cantidad
        print(f"Ingreso a {self.nombre}: +{cantidad}. Nuevo saldo: {self.saldo}")

    def retirar_dinero(self, cantidad):
        if cantidad > self.saldo:
            raise ValueError(f"Saldo insuficiente para {self.nombre}. No se pueden retirar {cantidad}.")

        self.saldo -= cantidad
        print(f"Retirada de {self.nombre}: -{cantidad}. Nuevo saldo: {self.saldo}")

    def transferir_dinero(self, destinatario, cantidad):
        print(f"Iniciando transferencia de {self.nombre} a {destinatario.nombre} por {cantidad}")

        try:
            self.retirar_dinero(cantidad)
            destinatario.agregar_dinero(cantidad)
            print("Transferencia completada correctamente.")

        except ValueError as e:
            print(f"Error en la transferencia: {e}")


print("Creando usuarios...")
alicia = UsuarioBanco("Alicia", 100, True)
daniel = UsuarioBanco("Daniel", 50, True)


print("Operación: Ingresar dinero a Daniel")
daniel.agregar_dinero(20)


print("Operación: Transferir de Daniel a Alicia")
daniel.transferir_dinero(alicia, 80)

print("Operación: Retirar dinero de Alicia")
try:
    alicia.retirar_dinero(50)
except ValueError as e:
    print(e)

print("RESUMEN:")
print(f"Saldo Alicia: {alicia.saldo}")
print(f"Saldo Daniel: {daniel.saldo}")
# Out:
# Creando usuarios...
# Operación: Ingresar dinero a Daniel
# Ingreso a Daniel: +20. Nuevo saldo: 70
# Operación: Transferir de Daniel a Alicia
# Iniciando transferencia de Daniel a Alicia por 80
# Error en la transferencia: Saldo insuficiente para Daniel. No se pueden retirar 80.
# Operación: Retirar dinero de Alicia
# Retirada de Alicia: -50. Nuevo saldo: 50
# RESUMEN:
# Saldo Alicia: 50
# Saldo Daniel: 70

# %% [markdown]
# 36. Crea una función llamada procesar_texto
#     - Procesa un texto según la opción especificada: contar_palabras, reemplazar_palabras o eliminar_palabra.
#     - Código a seguir:
#         - Crear una función contar_palabras que cuente el número de veces que aparece cada palabra en el texto y devuelva un diccionario.
#         - Crear una función reemplazar_palabras para sustituir una palabra_original por una palabra_nueva en el texto y devolver el texto modificado.
#         - Crear una función eliminar_palabra que elimine una palabra del texto y devuelva el texto sin ella.
#         - Crear la función procesar_texto que reciba un texto, una opción ("contar", "reemplazar", "eliminar") y un número variable de argumentos según la opción elegida.
#     - Caso de uso:
#         - Verificar el funcionamiento completo de procesar_texto.

# %%
def contar_palabras(texto):
    palabras = texto.split()
    diccionario = {}
    for palabra in palabras:
        if palabra in diccionario:
            diccionario[palabra] += 1
        else:
            diccionario[palabra] = 1
    return diccionario

def reemplazar_palabras(texto, palabra_original, palabra_nueva):
    return texto.replace(palabra_original, palabra_nueva)

def eliminar_palabra(texto, palabra_a_eliminar):
    texto_nuevo = texto.replace(palabra_a_eliminar, "")
    return texto_nuevo.strip()

def procesar_texto(texto, opcion, *args):
    if opcion == "contar":
        return contar_palabras(texto)
    elif opcion == "reemplazar":
        return reemplazar_palabras(texto, args[0], args[1])
    elif opcion == "eliminar":
        return eliminar_palabra(texto, args[0])
    else:
        return "Opción no válida."


texto_base = "hola mundo hola python mundo"

resultado_contar = procesar_texto(texto_base, "contar")
print(resultado_contar)

resultado_reemplazar = procesar_texto(texto_base, "reemplazar", "mundo", "universo")
print(resultado_reemplazar)

resultado_eliminar = procesar_texto(texto_base, "eliminar", "python")
print(resultado_eliminar)
# Out:
# {'hola': 2, 'mundo': 2, 'python': 1}
# hola universo hola python universo
# hola mundo hola  mundo

# %% [markdown]
# 37. Genera un programa que nos indique si es de noche, de día o de tarde según la hora proporcionada por el usuario.

# %%
def determinar_momento_dia():
    try:
        hora = int(input("Introduce la hora (formato 24h): "))
        if hora < 0 or hora > 23:
            print("Error: La hora debe estar entre 0 y 23.")
            return
        if 6 <= hora <= 12:
            print(f"Son las {hora}:00. Es de día")

        elif 13 <= hora <= 20:
            print(f"Son las {hora}:00. Es de tarde")

        else:
            print(f"Son las {hora}:00. Es de noche")

    except ValueError:
        print("Error: Por favor, introduce un número entero válido.")

determinar_momento_dia()
# Out:
# Son las 22:00. Es de noche

# %% [markdown]
# 38. Escribe un programa que determine qué calificación en texto tiene un alumno según su calificación numérica.
# - Reglas:
#     - 0 - 69: insuficiente
#     - 70 - 79: bien
#     - 80 - 89: muy bien
#     - 90 - 100: excelente

# %%
def determinar_calificacion():
    try:
        nota = int(input("Introduce la calificación numérica (0-100): "))

        if nota < 0 or nota > 100:
            print("Error: La nota debe estar entre 0 y 100.")
            return

        if 90 <= nota <= 100:
            print("Calificación: excelente")
        elif 80 <= nota <= 89:
            print("Calificación: muy bien")
        elif 70 <= nota <= 79:
            print("Calificación: bien")
        else:
            print("Calificación: insuficiente")

    except ValueError:
        print("Error: Debes introducir un número entero.")

determinar_calificacion()
# Out:
# Calificación: insuficiente

# %% [markdown]
# 39. Escribe una función que tome dos parámetros: figura (una cadena que puede ser "rectangulo", "circulo" o "triangulo") y datos (una tupla con los datos necesarios para calcular el área de la figura).

# %%
import math

def calcular_area(figura, datos):
    figura = figura.lower()

    if figura == "rectangulo":
        base, altura = datos
        return base * altura

    elif figura == "triangulo":
        base, altura = datos
        return (base * altura) / 2

    elif figura == "circulo":
        radio = datos[0]
        return math.pi * (radio ** 2)

    else:
        return "Error: Figura no reconocida."


print(f"Área Rectángulo: {calcular_area('rectangulo', (10, 5))}")

print(f"Área Triángulo: {calcular_area('triangulo', (10, 5))}")

print(f"Área Círculo: {calcular_area('circulo', (3,))}")
# Out:
# Área Rectángulo: 50
# Área Triángulo: 25.0
# Área Círculo: 28.274333882308138

# %% [markdown]
# 40. Escribe un programa en Python que utilice condicionales para determinar el monto final de una compra en una tienda en línea, después de aplicar un descuento. El programa debe:
#     - a. Solicitar al usuario el precio original de un artículo.
#     - b. Preguntar si tiene un cupón de descuento (respuesta sí o no).
#     - c. Si la respuesta es sí, solicitar el valor del cupón de descuento.
#     - d. Aplicar el descuento al precio original, siempre que el valor del cupón sea válido (mayor a cero).
#     - e. Mostrar el precio final de la compra, considerando o no el descuento.
#     - f. Usar estructuras de control de flujo (if, elif, else) para llevar a cabo las acciones.

# %%
def calcular_precio_final():
    try:
        precio_original = float(input("Introduce el precio original del artículo: "))
        tiene_cupon = input("¿Tienes un cupón de descuento? (s/n): ").lower().strip()
        precio_final = precio_original

        if tiene_cupon == "s":
            valor_cupon = float(input("Introduce el valor del cupón de descuento: "))

            if valor_cupon > 0:
                precio_final = precio_original - valor_cupon
                if precio_final < 0:
                    precio_final = 0
                print(f"Descuento de {valor_cupon} aplicado correctamente.")
            else:
                print("El valor del cupón no es válido (debe ser mayor a 0). No se aplicará descuento.")

        elif tiene_cupon == "n":
            print("No se aplicará ningún descuento.")

        else:
            print("Respuesta no reconocida. Se asumirá que no hay cupón.")

        print(f"--- El precio final de la compra es: {precio_final:.2f} ---")

    except ValueError:
        print("Error: Por favor, introduce valores numéricos válidos para el precio y el cupón.")

calcular_precio_final()
# Out:
# Descuento de 50.0 aplicado correctamente.
# --- El precio final de la compra es: 19.00 ---
